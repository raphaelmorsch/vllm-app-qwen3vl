# %%
import time
import requests
import numpy as np

# %%
VLLM_ENDPOINT = "http://qwen3-vl-4b-instruct-predictor.qwen3.svc.cluster.local:8080/v1/chat/completions"
MODEL_NAME = "qwen3-vl-4b-instruct"

IMAGE_LIST_FILE = "images.txt"
REQUESTS_PER_IMAGE = 5  # repete cada imagem
PROMPT = "Descreva a imagem em português."

headers = {
    "Content-Type": "application/json"
}

# %%
with open(IMAGE_LIST_FILE, "r") as f:
    image_urls = [line.strip() for line in f if line.strip()]

print(f"{len(image_urls)} imagens carregadas.")
# Out:
# 10 imagens carregadas.

# %%
latencies = []
responses = []

print("\nIniciando inferências multimodais...\n")

request_id = 1

for image_url in image_urls:
    for _ in range(REQUESTS_PER_IMAGE):
        payload = {
            "model": MODEL_NAME,
            "messages": [
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": PROMPT},
                        {
                            "type": "image_url",
                            "image_url": {"url": image_url}
                        }
                    ]
                }
            ],
            "max_tokens": 120,
            "temperature": 0.2
        }

        start = time.time()
        resp = requests.post(
            VLLM_ENDPOINT,
            headers=headers,
            json=payload,
            timeout=120
        )
        elapsed = time.time() - start

        latencies.append(elapsed)

        if resp.status_code == 200:
            output = resp.json()["choices"][0]["message"]["content"]
            responses.append(output)

            print(f"[{request_id}] OK - {elapsed:.2f}s")
            print(f"Imagem: {image_url}")
            print(f"Resposta: {output}\n")
        else:
            print(f"[{request_id}] ERRO {resp.status_code} - {elapsed:.2f}s")

        request_id += 1
# Out:
# Iniciando inferências multimodais...
#
# [1] OK - 4.56s
# Imagem: https://img.odcdn.com.br/wp-content/uploads/2021/12/placa-mercosul-o-que-e.jpg
# Resposta: A imagem mostra um close-up da frente de um carro branco, com foco na placa de licença. O veículo é uma Fiat, como indicado pelo emblema no capô. A placa é brasileira, com a bandeira do Brasil no canto superior direito e a palavra "BRASIL" no topo. O número da placa é "0ZL7H33", com o código "BR" no canto inferior esquerdo, indicando que o carro está registrado no Brasil. O carro está estacionado em uma rua,
#
# [2] OK - 4.25s
# Imagem: https://img.odcdn.com.br/wp-content/uploads/2021/12/placa-mercosul-o-que-e.jpg
# Resposta: A imagem mostra um close-up da frente de um carro branco, com foco na placa de licença. O veículo é uma Fiat, como indicado pelo emblema no capô. A placa é brasileira, com a sigla "BR" no canto esquerdo e a palavra "BRASIL" no topo, além da bandeira do Brasil no canto direito. O número da placa é "OZL7H33". Ao fundo, desfocadas, há outras carros brancos estacionados em uma
#
# [3] OK - 4.26s
# Imagem: https://img.odcdn.com.br/wp-content/uploads/2021/12/placa-mercosul-o-que-e.jpg
# Resposta: A imagem mostra um close-up da placa de licença de um carro branco, estacionado em uma rua. O carro é uma Fiat, como indicado pelo emblema no capô. A placa é brasileira, com o código "BR" e a palavra "BRASIL" em destaque. O número da placa é "OZL7H33". A placa possui um design com uma faixa azul no topo e um pequeno brasão da bandeira do Brasil no canto direito. Ao fundo, há outros car
#
# [4] OK - 4.27s
# Imagem: https://img.odcdn.com.br/wp-content/uploads/2021/12/placa-mercosul-o-que-e.jpg
# Resposta: A imagem mostra um close-up da frente de um carro branco, com foco na placa de licença. O veículo é uma Fiat, como indicado pelo emblema no capô. A placa é brasileira, com o código "BR" e a palavra "BRASIL" em azul no topo. O número da placa é "OZL7H33", e à direita, há o pequeno brasão da bandeira do Brasil. A placa está presa à grade frontal do carro, que é preta. Ao fundo
#
# [5] OK - 4.26s
# Imagem: https://img.odcdn.com.br/wp-content/uploads/2021/12/placa-mercosul-o-que-e.jpg
# Resposta: A imagem mostra um close-up da frente de um carro branco, com foco na placa de licença. O veículo é uma Fiat, como indicado pelo emblema no capô. A placa é brasileira, com a inscrição "BRASIL" e a bandeira do Brasil no canto superior direito. O número da placa é "0ZL7H33", com o código "BR" no canto superior esquerdo, indicando que o carro está registrado no Brasil. Ao fundo, desfocado, há outro
#
# [6] OK - 4.53s
# Imagem: https://quatrorodas.abril.com.br/wp-content/uploads/2017/08/aaa0001.jpg?quality=70&strip=info&w=720&crop=1
# Resposta: A imagem mostra um carro conversível da marca Ford, modelo Escort, estacionado em um pátio de pedras. O veículo é de cor cinza-escura e possui um design característico dos anos 1980, com faróis redondos e um emblema da Ford no centro do capô. A placa de licença, que está em formato de "AAA 0001", é brasileira e indica que o carro está registrado no estado de São Paulo. O carro está estacionado em frente a uma parede de pedra
#
# [7] OK - 4.23s
# Imagem: https://quatrorodas.abril.com.br/wp-content/uploads/2017/08/aaa0001.jpg?quality=70&strip=info&w=720&crop=1
# Resposta: A imagem mostra um carro conversível da marca Ford, modelo Escort, estacionado em um pátio de pedras. O veículo é de cor escura, provavelmente preta ou cinza escuro, e possui um design característico dos anos 1980, com faróis grandes e uma grade frontal com o logotipo da Ford. A placa de licença, que está em formato de "AAA 0001", é brasileira, indicando que o carro está localizado no Brasil.
#
# O carro está estacionado em um cam
#
# [8] OK - 4.22s
# Imagem: https://quatrorodas.abril.com.br/wp-content/uploads/2017/08/aaa0001.jpg?quality=70&strip=info&w=720&crop=1
# Resposta: A imagem mostra um carro conversível da marca Ford, modelo Escort, estacionado em um pátio de pedras. O veículo é de cor cinza escura e possui um design característico dos anos 1990, com faróis redondos e um para-choque dianteiro com duas luzes auxiliares circulares. A placa de licença, que está em formato de "AAA 0001", é brasileira e indica que o carro está registrado no estado de São Paulo. O carro está estacionado em um cam
#
# [9] OK - 4.22s
# Imagem: https://quatrorodas.abril.com.br/wp-content/uploads/2017/08/aaa0001.jpg?quality=70&strip=info&w=720&crop=1
# Resposta: A imagem mostra um carro conversível da marca Ford, modelo Escort, estacionado em um pátio de pedras. O veículo é de cor cinza-escura e possui um design característico dos anos 1990, com faróis grandes e uma grade frontal com o logotipo da Ford. A placa de licença, que está em formato de "AAA 0001", é brasileira e indica que o carro está registrado no estado de São Paulo. O carro está estacionado em um caminho de pedras, com uma parede
#
# [10] OK - 4.22s
# Imagem: https://quatrorodas.abril.com.br/wp-content/uploads/2017/08/aaa0001.jpg?quality=70&strip=info&w=720&crop=1
# Resposta: A imagem mostra um carro conversível da marca Ford, modelo Escort, estacionado em um pátio de pedras. O veículo é de cor cinza escura e possui um design característico dos anos 1980, com faróis grandes e redondos, uma grade frontal com o logotipo da Ford e um para-choque com duas luzes circulares adicionais. A placa de licença, que está em formato de "AAA 0001", é de um país que usa o sistema de placas brasileiro, indicando
#
# [11] OK - 4.38s
# Imagem: https://www.shutterstock.com/image-photo/salvador-bahia-brazil-august-21-260nw-2354172265.jpg
# Resposta: A imagem mostra a frente de um carro branco da marca Chevrolet, com foco na grade frontal e na placa de licença. O logotipo da Chevrolet, um emblema dourado em forma de "C" estilizado, está centralizado na grade. A placa de licença, que pertence ao estado de Minas Gerais (MG), exibe o número "RCV3C89" em letras pretas sobre fundo azul. O carro possui faróis modernos e uma grade com um padrão de listras horizont
#
# [12] OK - 4.29s
# Imagem: https://www.shutterstock.com/image-photo/salvador-bahia-brazil-august-21-260nw-2354172265.jpg
# Resposta: A imagem mostra a frente de um carro branco da marca Chevrolet, com foco na grade frontal e na placa de licença. O logotipo da Chevrolet, um emblema dourado em forma de "C" estilizado, está centralizado na grade. A placa de licença, que pertence ao estado do Rio Grande do Norte (RN), exibe o número "RCV3C89" em letras pretas sobre fundo azul. O carro possui faróis modernos e uma grade com um padrão de listras horizont
#
# [13] OK - 4.18s
# Imagem: https://www.shutterstock.com/image-photo/salvador-bahia-brazil-august-21-260nw-2354172265.jpg
# Resposta: A imagem mostra a frente de um carro branco da marca Chevrolet, com foco na grade frontal e na placa de licença. O logotipo da Chevrolet, um emblema dourado em forma de "C" estilizado, está centralizado na grade. A placa de licença, que pertence ao estado de Minas Gerais (MG), exibe o número "RCV3C89" em letras pretas sobre fundo azul. O carro possui faróis modernos e um design de grade com listras horizontais.
#
# [14] OK - 4.18s
# Imagem: https://www.shutterstock.com/image-photo/salvador-bahia-brazil-august-21-260nw-2354172265.jpg
# Resposta: A imagem mostra a frente de um carro branco da marca Chevrolet, com foco na grade frontal e na placa de licença. O logotipo da Chevrolet, um emblema dourado em forma de "C" estilizado, está centralizado na grade. A placa de licença, que está fixada na parte inferior da grade, é azul com letras e números brancos e exibe a inscrição "RVC3C89". O carro possui faróis modernos e um design de grade com linhas horizontais.
#
# [15] OK - 4.19s
# Imagem: https://www.shutterstock.com/image-photo/salvador-bahia-brazil-august-21-260nw-2354172265.jpg
# Resposta: A imagem mostra a frente de um carro branco da marca Chevrolet, com foco na grade frontal e na placa de licença. O logotipo da Chevrolet, um emblema dourado em forma de "C" estilizado, está centralizado na grade. A placa de licença, que está em um formato retangular com fundo azul e letras e números brancos, exibe a inscrição "RCV3C89" e a sigla "BAHIA" no topo, indicando que o veículo está registrado no estado
#
# [16] OK - 4.37s
# Imagem: https://http2.mlstatic.com/D_NQ_NP_962512-MLA89579224871_082025-B.webp
# Resposta: A imagem mostra um carro clássico Volkswagen Fusca, de cor azul-claro, estacionado em um ambiente natural com gramado verde e árvores ao fundo. O veículo está posicionado em um caminho de terra ou asfalto, com a frente voltada para o observador. O Fusca apresenta o design icônico da época, com faróis redondos, para-choques cromados, espelhos retrovisores laterais e lanternas de posição laranja nas laterais da frente. A pl
#
# [17] OK - 4.21s
# Imagem: https://http2.mlstatic.com/D_NQ_NP_962512-MLA89579224871_082025-B.webp
# Resposta: A imagem mostra um carro clássico Volkswagen Fusca, de cor azul-claro, estacionado em um ambiente natural com gramado verde e árvores ao fundo. O veículo está posicionado em um caminho de terra ou asfalto, com a frente voltada para o observador. O Fusca possui o design icônico da época, com faróis redondos, para-choques cromados, lanternas de advertência laranja nas laterais da frente e espelhos retrovisores laterais. A pl
#
# [18] OK - 4.24s
# Imagem: https://http2.mlstatic.com/D_NQ_NP_962512-MLA89579224871_082025-B.webp
# Resposta: A imagem mostra um carro clássico Volkswagen Fusca, de cor azul-claro, estacionado em um ambiente ao ar livre. O veículo está posicionado em um caminho de terra, com um gramado verde e arborizado ao fundo, sob luz solar que cria sombras suaves. O Fusca apresenta o design icônico da época, com faróis redondos, para-choques cromados, espelhos retrovisores laterais e uma placa de licença brasileira com a inscrição "BRA
#
# [19] OK - 4.21s
# Imagem: https://http2.mlstatic.com/D_NQ_NP_962512-MLA89579224871_082025-B.webp
# Resposta: A imagem mostra um Volkswagen Fusca clássico, de cor azul-claro, estacionado em um ambiente natural com gramado verde e árvores ao fundo. O carro está posicionado em um caminho de terra, com a frente voltada para o observador, exibindo sua característica forma arredondada e design icônico. A placa de licença, que indica "BRASIL", apresenta o número "BRA7S19". O veículo possui faróis redondos, espelhos retrovis
#
# [20] OK - 4.21s
# Imagem: https://http2.mlstatic.com/D_NQ_NP_962512-MLA89579224871_082025-B.webp
# Resposta: A imagem mostra um carro clássico Volkswagen Fusca, de cor azul-claro, estacionado em um ambiente ao ar livre. O veículo está posicionado em um caminho de terra, com um gramado verde e arborizado ao fundo, sob luz solar que cria sombras suaves. O Fusca apresenta o design icônico da época, com faróis redondos, para-choques cromados, lanternas de advertência laranja nas laterais e espelhos retrovisores laterais. A placa de
#
# [21] OK - 4.56s
# Imagem: https://www.automaistv.com.br/wp-content/uploads/2023/01/fiat_bravo_sporting_7_edited-1200x719.jpg
# Resposta: A imagem mostra um carro Fiat, modelo Mobi, de cor vermelha vibrante, em movimento sobre uma estrada de asfalto que curva suavemente. O veículo está posicionado em um ângulo frontal, destacando sua frente com faróis modernos, grade de entrada com o emblema da Fiat no centro e um para-choque inferior com luzes diurnas. A placa de licença, que indica "MG - BELO HORIZONTE" e o número "PVI-6113", está claram
#
# [22] OK - 4.28s
# Imagem: https://www.automaistv.com.br/wp-content/uploads/2023/01/fiat_bravo_sporting_7_edited-1200x719.jpg
# Resposta: A imagem mostra um carro Fiat, modelo Mobi, de cor vermelha vibrante, em movimento sobre uma estrada de asfalto que curva suavemente. O veículo está posicionado em um ângulo frontal, destacando sua dianteira com faróis grandes e modernos, grade de entrada de ar com padrão de malha e o emblema da marca Fiat no centro. A placa de licença, com a inscrição "MG - BELO HORIZONTE" e o número "PVI-6113",
#
# [23] OK - 4.27s
# Imagem: https://www.automaistv.com.br/wp-content/uploads/2023/01/fiat_bravo_sporting_7_edited-1200x719.jpg
# Resposta: A imagem mostra um carro Fiat, modelo Mobi, de cor vermelha vibrante, em movimento sobre uma estrada de asfalto que curva suavemente. O veículo está posicionado em um ângulo frontal, destacando sua dianteira com faróis modernos e uma grade de entrada de ar com um padrão de malha. O logotipo da Fiat está centralizado na grade, e abaixo dele, há uma placa de licença com a inscrição "MG - BELO HORIZONTE" e o número "PVI
#
# [24] OK - 4.27s
# Imagem: https://www.automaistv.com.br/wp-content/uploads/2023/01/fiat_bravo_sporting_7_edited-1200x719.jpg
# Resposta: A imagem mostra um carro Fiat, modelo Mobi, de cor vermelha vibrante, em movimento sobre uma estrada de asfalto que curva suavemente. O veículo está posicionado em um ângulo frontal, destacando sua frente com faróis grandes e modernos, grade de entrada com padrão de malha e o emblema da marca Fiat no centro. A placa de licença, com a inscrição "MG - BELO HORIZONTE" e o número "PVI-6113", está claramente
#
# [25] OK - 4.27s
# Imagem: https://www.automaistv.com.br/wp-content/uploads/2023/01/fiat_bravo_sporting_7_edited-1200x719.jpg
# Resposta: A imagem mostra um carro Fiat, modelo Mobi, de cor vermelha vibrante, em movimento sobre uma estrada de asfalto que curva suavemente. O veículo está posicionado em um ângulo frontal, destacando sua dianteira com faróis modernos, grade com padrão de malha e o emblema da marca Fiat no centro. A placa de licença, com a inscrição "MG - BELO HORIZONTE" e o número "PVI-6113", está claramente visível
#
# [26] OK - 4.51s
# Imagem: https://conteudo.imguol.com.br/2012/06/04/citroen-c3-vermelho-com-placa-de-porto-real-rj-sede-da-psa-foi-avistado-estacionado-em-shopping-center-de-sao-jose-dos-campos-sp-1338853069907_615x470.jpg
# Resposta: A imagem mostra um carro vermelho estacionado em um estacionamento ao ar livre, com outros veículos ao fundo. O carro é um modelo da marca Citroën, identificado pelo logotipo da marca na grade frontal. A placa de licença do veículo é "KOU-4533", que indica que o carro está registrado no estado do Rio Grande do Sul, Brasil. O carro possui faróis grandes e modernos, uma grade preta com acabamento cromado e rodas de liga leve. Ao fundo, é
#
# [27] OK - 4.20s
# Imagem: https://conteudo.imguol.com.br/2012/06/04/citroen-c3-vermelho-com-placa-de-porto-real-rj-sede-da-psa-foi-avistado-estacionado-em-shopping-center-de-sao-jose-dos-campos-sp-1338853069907_615x470.jpg
# Resposta: A imagem mostra um carro vermelho estacionado em um estacionamento ao ar livre, com outros veículos ao fundo. O carro é um modelo da marca Citroën, identificado pelo logotipo da marca na grade frontal. A placa de licença do veículo é "KOU-4533", que indica que o carro está registrado no estado do Rio Grande do Sul, Brasil. O carro possui faróis grandes e modernos, uma grade preta com acabamento cromado e rodas de liga leve. Ao fundo, é
#
# [28] OK - 4.22s
# Imagem: https://conteudo.imguol.com.br/2012/06/04/citroen-c3-vermelho-com-placa-de-porto-real-rj-sede-da-psa-foi-avistado-estacionado-em-shopping-center-de-sao-jose-dos-campos-sp-1338853069907_615x470.jpg
# Resposta: A imagem mostra um carro vermelho da marca Citroën, modelo C3, estacionado em uma rua ou estacionamento. O veículo está posicionado em primeiro plano, com a frente voltada para o observador. O carro possui um design moderno, com faróis grandes e uma grade frontal preta com o logotipo da Citroën em destaque. A placa de licença, que está no centro da grade, é brasileira e lê "KOU-4533". Ao fundo, há outros carros estacionados
#
# [29] OK - 4.22s
# Imagem: https://conteudo.imguol.com.br/2012/06/04/citroen-c3-vermelho-com-placa-de-porto-real-rj-sede-da-psa-foi-avistado-estacionado-em-shopping-center-de-sao-jose-dos-campos-sp-1338853069907_615x470.jpg
# Resposta: A imagem mostra um carro vermelho da marca Citroën, modelo C3, estacionado em um estacionamento ao ar livre. O veículo possui um design moderno, com faróis grandes e uma grade frontal preta com o logotipo da Citroën em prata. A placa de licença é brasileira, com a numeração "KOU-4533". Ao fundo, há outros carros estacionados, incluindo um preto com o logotipo da Volkswagen. O cenário sugere um dia ensolar
#
# [30] OK - 4.22s
# Imagem: https://conteudo.imguol.com.br/2012/06/04/citroen-c3-vermelho-com-placa-de-porto-real-rj-sede-da-psa-foi-avistado-estacionado-em-shopping-center-de-sao-jose-dos-campos-sp-1338853069907_615x470.jpg
# Resposta: A imagem mostra um carro vermelho estacionado em um estacionamento ao ar livre, com outros veículos ao fundo. O carro é um modelo da marca Citroën, identificado pelo logotipo da marca na grade frontal. A placa de licença do veículo é "KOU-4533", que indica que o carro está registrado no estado de São Paulo, Brasil. O carro possui faróis grandes e modernos, uma grade preta com detalhes cromados e rodas de liga leve. Ao fundo, é possível ver
#
# [31] OK - 4.68s
# Imagem: https://image1.mobiauto.com.br/images/api/images/v1.0/490781378/transform/fl_progressive,f_webp,q_100,w_1200
# Resposta: A imagem mostra um carro SUV da marca Nissan, modelo Kicks, de cor branca, estacionado em um ambiente externo com vegetação ao fundo. O veículo apresenta um design moderno, com uma grade frontal preta e o logotipo da Nissan no centro. Os faróis são longos e estreitos, com luzes diurnas LED. A carroceria possui detalhes em preto nas molduras das janelas, nas proteções laterais e na parte inferior do para-choque. As rodas são de liga leve
#
# [32] OK - 4.31s
# Imagem: https://image1.mobiauto.com.br/images/api/images/v1.0/490781378/transform/fl_progressive,f_webp,q_100,w_1200
# Resposta: A imagem mostra um carro SUV da marca Nissan, modelo Kicks, de cor branca, estacionado em um ambiente externo com vegetação ao fundo. O veículo apresenta um design moderno, com uma grade frontal preta e o logotipo da Nissan no centro. Os faróis são longos e estreitos, com luzes diurnas LED. A carroceria possui detalhes em preto nas molduras das janelas, nas proteções laterais e na parte inferior do para-choque. As rodas são de liga leve
#
# [33] OK - 4.30s
# Imagem: https://image1.mobiauto.com.br/images/api/images/v1.0/490781378/transform/fl_progressive,f_webp,q_100,w_1200
# Resposta: A imagem mostra um carro SUV da marca Nissan, modelo Kicks, de cor branca, estacionado em um local com pavimento asfaltado e cercado por vegetação verde. O veículo apresenta um design moderno, com uma grade frontal preta e o logotipo da Nissan no centro. Os faróis são longos e estreitos, com luzes diurnas LED. As rodas são de liga leve com um design de múltiplos raios, e o carro possui detalhes em preto nas molduras das janel
#
# [34] OK - 4.29s
# Imagem: https://image1.mobiauto.com.br/images/api/images/v1.0/490781378/transform/fl_progressive,f_webp,q_100,w_1200
# Resposta: A imagem mostra um carro SUV da marca Nissan, modelo Kicks, de cor branca, estacionado em um local com pavimento asfaltado e cercado por vegetação verde. O veículo apresenta um design moderno, com uma grade frontal preta e o logotipo da Nissan no centro. Os faróis são longos e estreitos, com luzes diurnas LED. A carroceria possui detalhes em preto nas molduras das janelas, nas proteções laterais e na parte inferior do para-choque. As rod
#
# [35] OK - 4.29s
# Imagem: https://image1.mobiauto.com.br/images/api/images/v1.0/490781378/transform/fl_progressive,f_webp,q_100,w_1200
# Resposta: A imagem mostra um carro SUV da marca Nissan, modelo Kicks, de cor branca, estacionado em um ambiente externo com vegetação ao fundo. O veículo apresenta um design moderno, com uma grade frontal preta e o logotipo da Nissan no centro. Os faróis são longos e estreitos, com luzes diurnas LED. A carroceria possui detalhes em preto nas molduras das janelas, nas proteções laterais e na parte inferior do para-choque. As rodas são de liga leve
#
# [36] OK - 4.59s
# Imagem: https://revistacarro.com.br/wp-content/uploads/2021/07/Renault-Captur-Iconic-2022-TCe_3.jpg
# Resposta: A imagem mostra um Renault Kwid, um carro compacto de cor dourada metálica, em movimento sobre uma estrada asfaltada. O veículo está capturado em um ângulo de três quartos, destacando sua frente e lado direito. A placa de licença, visível na frente, é brasileira e lê "RHD5H38".
#
# O carro possui um design moderno, com faróis de LED estreitos e um para-choque dianteiro com moldura cromada. O capô
#
# [37] OK - 4.27s
# Imagem: https://revistacarro.com.br/wp-content/uploads/2021/07/Renault-Captur-Iconic-2022-TCe_3.jpg
# Resposta: A imagem mostra um Renault Kwid, um carro compacto de cor dourada metálica, em movimento sobre uma estrada asfaltada. O veículo está capturado em um ângulo de três quartos, destacando sua frente e lado direito. A placa de licença, visível na frente, é "RHD5H38" e pertence ao Brasil.
#
# O carro possui um design moderno, com faróis de LED estreitos e um para-choque dianteiro com moldura cromada. O cap
#
# [38] OK - 4.28s
# Imagem: https://revistacarro.com.br/wp-content/uploads/2021/07/Renault-Captur-Iconic-2022-TCe_3.jpg
# Resposta: A imagem mostra um Renault Kwid, um carro compacto de cor dourada metálica, em movimento sobre uma estrada asfaltada. O veículo está capturado em um ângulo de três quartos, destacando sua frente e lado direito. A placa de licença, visível na frente, é brasileira, com o número "RHD5H38". O carro possui faróis modernos, grade frontal com o logotipo da Renault e rodas de liga leve escuras. O fundo da imagem está
#
# [39] OK - 4.28s
# Imagem: https://revistacarro.com.br/wp-content/uploads/2021/07/Renault-Captur-Iconic-2022-TCe_3.jpg
# Resposta: A imagem mostra um Renault Kwid, um carro compacto de cor dourada metálica, em movimento sobre uma estrada asfaltada. O veículo está capturado em um ângulo de três quartos, destacando sua frente e lado direito. A placa de licença, visível na frente, é brasileira e lê "RHD5H38".
#
# O carro possui um design moderno, com faróis de LED estreitos e um para-choque dianteiro com moldura cromada. A grade frontal
#
# [40] OK - 4.28s
# Imagem: https://revistacarro.com.br/wp-content/uploads/2021/07/Renault-Captur-Iconic-2022-TCe_3.jpg
# Resposta: A imagem mostra um Renault Kwid, um carro compacto de cor dourada metálica, em movimento sobre uma estrada asfaltada. O veículo está capturado em um ângulo de três quartos, destacando sua frente e lado direito. A placa de licença, visível na frente, é brasileira e lê "RHD5H38".
#
# O carro possui um design moderno, com faróis de LED estreitos e um para-choque dianteiro com moldura cromada. A grade frontal
#
# [41] OK - 4.44s
# Imagem: https://newr7-r7-prod.web.arc-cdn.net/resizer/v2/HL7VWBQLSZMC5GAV4LITAVOCHY.jpg?auth=22425b80c399a343d066ee5b391bead6ef0ef9b4b7e0bb5f2c755972f49d7f4d&width=771&height=419
# Resposta: A imagem mostra um SUV da marca Hyundai, modelo Kona, na cor cinza metálico, estacionado em um ambiente externo com pavimento asfaltado e vegetação ao fundo. O veículo apresenta um design moderno e agressivo, com uma grade frontal em formato de grade de malha preta, faróis de LED com formato alongado e uma linha de teto que se estende até o para-choque dianteiro. As rodas são de liga leve com um design de múltiplos raios, e
#
# [42] OK - 4.24s
# Imagem: https://newr7-r7-prod.web.arc-cdn.net/resizer/v2/HL7VWBQLSZMC5GAV4LITAVOCHY.jpg?auth=22425b80c399a343d066ee5b391bead6ef0ef9b4b7e0bb5f2c755972f49d7f4d&width=771&height=419
# Resposta: A imagem mostra um SUV da marca Hyundai, modelo Tucson, em uma cor cinza metálica. O veículo está estacionado em um pavimento asfaltado, com um fundo de vegetação e árvores ao redor, sugerindo um ambiente residencial ou de parque.
#
# Detalhes visíveis:
#
# - **Dianteiro**: A grade frontal é grande e com um padrão de malha, com o logotipo da Hyundai no centro. Os faróis são longos e estreitos, com luzes diurnas LED integradas
#
# [43] OK - 4.24s
# Imagem: https://newr7-r7-prod.web.arc-cdn.net/resizer/v2/HL7VWBQLSZMC5GAV4LITAVOCHY.jpg?auth=22425b80c399a343d066ee5b391bead6ef0ef9b4b7e0bb5f2c755972f49d7f4d&width=771&height=419
# Resposta: A imagem mostra um SUV da marca Hyundai, modelo Tucson, em uma cor cinza metálica. O veículo está estacionado em um pavimento asfaltado, com um fundo de vegetação e árvores ao redor, sugerindo um ambiente residencial ou de parque.
#
# Detalhes visíveis:
# - **Dianteiro**: A grade frontal possui um padrão de grade de malha escura, com o logotipo da Hyundai no centro. Os faróis são longos e estreitos, com iluminação LED. Ab
#
# [44] OK - 4.25s
# Imagem: https://newr7-r7-prod.web.arc-cdn.net/resizer/v2/HL7VWBQLSZMC5GAV4LITAVOCHY.jpg?auth=22425b80c399a343d066ee5b391bead6ef0ef9b4b7e0bb5f2c755972f49d7f4d&width=771&height=419
# Resposta: A imagem mostra um SUV da marca Hyundai, modelo Tucson, em uma cor cinza metálica. O veículo está estacionado em um pavimento asfaltado, com um fundo de vegetação e árvores ao redor, sugerindo um ambiente residencial ou de parque.
#
# Detalhes visíveis:
# - **Dianteiro**: A grade frontal possui um padrão de malha escura, com o logotipo da Hyundai no centro. Os faróis são longos e estreitos, com luzes diurnas LED integradas.
#
# [45] OK - 4.24s
# Imagem: https://newr7-r7-prod.web.arc-cdn.net/resizer/v2/HL7VWBQLSZMC5GAV4LITAVOCHY.jpg?auth=22425b80c399a343d066ee5b391bead6ef0ef9b4b7e0bb5f2c755972f49d7f4d&width=771&height=419
# Resposta: A imagem mostra um SUV da marca Hyundai, modelo Tucson, na cor cinza metálico, estacionado em uma rua asfaltada. O veículo apresenta um design moderno e agressivo, com uma grade frontal em formato de grade de malha, faróis de LED estilizados e um para-choque dianteiro com entradas de ar proeminentes. As rodas são de liga leve com um design de múltiplos raios, e o carro possui um acabamento em preto na parte inferior das portas e
#
# [46] OK - 4.72s
# Imagem: https://midias.agazeta.com.br/2024/07/31/fiat-pulse-s-design-2368459-article.jpg
# Resposta: A imagem mostra um carro SUV branco da marca Fiat, estacionado em um local com piso de pedras, ao lado de um corpo d'água. O veículo possui detalhes em preto, como as jantes, os espelhos retrovisores, as molduras das janelas e os para-choques, além de um teto escuro. A placa de licença é brasileira, com a numeração "SYG-9F95". Ao fundo, há um mar azul com algumas embarcações e uma ilha
#
# [47] OK - 4.32s
# Imagem: https://midias.agazeta.com.br/2024/07/31/fiat-pulse-s-design-2368459-article.jpg
# Resposta: A imagem mostra um carro SUV branco, modelo Fiat Toro, estacionado em um local com piso de pedras, próximo a uma praia ou litoral. O veículo possui detalhes em preto, como as rodas, os espelhos retrovisores, as molduras das janelas e os para-choques, além de um teto preto. A placa de licença é brasileira, com o número "SYG-9F95".
#
# O cenário ao fundo é composto por um corpo d'água azul
#
# [48] OK - 4.31s
# Imagem: https://midias.agazeta.com.br/2024/07/31/fiat-pulse-s-design-2368459-article.jpg
# Resposta: A imagem mostra um carro SUV branco, modelo Fiat Toro, estacionado em um local com piso de pedras, ao lado de um corpo d'água. O veículo possui detalhes em preto, como as rodas, os espelhos retrovisores, as molduras das janelas e os para-choques, além de um teto preto. A placa de licença é brasileira, com a numeração "SYG-9F95". Ao fundo, há um lago ou mar com ilhas e montanhas
#
# [49] OK - 4.31s
# Imagem: https://midias.agazeta.com.br/2024/07/31/fiat-pulse-s-design-2368459-article.jpg
# Resposta: A imagem mostra um carro SUV da marca Fiat, modelo Tipo, estacionado em um local com vista para o mar. O veículo é branco com detalhes em preto, incluindo as rodas, os espelhos retrovisores, as molduras das janelas e os para-choques. A placa de licença é brasileira, com a numeração "SYG-9F95".
#
# O carro está posicionado sobre um pavimento de pedras, típico de áreas urbanas costeiras, com grama ao lado. Ao
#
# [50] OK - 4.31s
# Imagem: https://midias.agazeta.com.br/2024/07/31/fiat-pulse-s-design-2368459-article.jpg
# Resposta: A imagem mostra um carro SUV da marca Fiat, modelo Tipo, estacionado em um local com vista para o mar. O veículo é branco com detalhes em preto, incluindo as rodas, os espelhos retrovisores, as molduras das janelas e os para-choques. A placa de licença é brasileira, com o número "SYG-9F95".
#
# O carro está posicionado sobre um pavimento de pedras, com grama ao lado. Ao fundo, há um corpo d'água azul

# %%
latencies_np = np.array(latencies)

p50 = np.percentile(latencies_np, 50)
p95 = np.percentile(latencies_np, 95)
avg = latencies_np.mean()

print("\n==============================")
print("📊 Resultados Multimodais")
print("==============================")
print(f"Total de requisições : {len(latencies)}")
print(f"Latência média       : {avg:.2f}s")
print(f"P50                  : {p50:.2f}s")
print(f"P95                  : {p95:.2f}s")
# Out:
# ==============================
# 📊 Resultados Multimodais
# ==============================
# Total de requisições : 50
# Latência média       : 4.31s
# P50                  : 4.27s
# P95                  : 4.58s
